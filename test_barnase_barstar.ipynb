# %%
import pynterpred as pnt

# %%
from simtk import unit

# %%
receptor = pnt.receptor('testsystems/Barnase-Barstar/Barnase.pdb','amber14-all.xml',pH=7.0)

# %%
ligand = pnt.ligand('testsystems/Barnase-Barstar/Barstar.pdb','amber14-all.xml',pH=7.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-14914e248eda> in <module>()
# ----> 1 ligand = pnt.ligand('testsystems/Barnase-Barstar/Barstar.pdb','amber14-all.xml',pH=7.0)
#
# ~/Trabajo/Proyectos/pynterpred/pynterpred.py in __init__(self, pdb_file, forcefield, pH, addHs, center)
#      46             self.pH         = pH
#      47             if addHs:
# ---> 48                 self.__addHs_log = self.modeller.addHydrogens(self.forcefield, pH=self.pH)
#      49             self.topology  = self.modeller.getTopology()
#      50             self.positions = self.modeller.getPositions()
#
# ~/Myusr/opt/miniconda3/envs/omnia3/lib/python3.6/site-packages/simtk/openmm/app/modeller.py in addHydrogens(self, forcefield, pH, variants, platform)
#     840             # Use the ForceField the user specified.
#     841
# --> 842             system = forcefield.createSystem(newTopology, rigidWater=False, nonbondedMethod=CutoffNonPeriodic)
#     843             atoms = list(newTopology.atoms())
#     844             for i in range(system.getNumParticles()):
#
# ~/Myusr/opt/miniconda3/envs/omnia3/lib/python3.6/site-packages/simtk/openmm/app/forcefield.py in createSystem(self, topology, nonbondedMethod, nonbondedCutoff, constraints, rigidWater, removeCMMotion, hydrogenMass, residueTemplates, ignoreExternalBonds, **args)
#    1126                             break
#    1127             if matches is None:
# -> 1128                 raise ValueError('No template found for residue %d (%s).  %s' % (res.index+1, res.name, _findMatchErrors(self, res)))
#    1129             else:
#    1130                 data.recordMatchedAtomParameters(res, template, matches)
#
# ValueError: No template found for residue 22 (LYS).  The set of atoms is similar to ASN, but it is missing 2 atoms.
