# %%
import molsysmt as msmt
# Out:
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDFLab_dev/lib/python3.6/site-packages/MDAnalysis/due.py:88: UserWarning: No module named 'duecredit'
#   warnings.warn(str(err))

# %%
tubulin_complex = msmt.load('PDB:1tub', pdbfix=True)

# %%
tubulin_complex.view()
# Out:
# NGLWidget()

# %%
tubulin_A, tubulin_B = tubulin_complex.get_proteins(verbose=True)

# %%
tubulin_A.write('tubulin_A.pdb')

# %%
tubulin_B.write('tubulin_B.pdb')
