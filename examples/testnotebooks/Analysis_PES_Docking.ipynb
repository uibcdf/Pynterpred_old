# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import os
import sys

import networkx as nx
import kinnetmt as knmt
import pynterpred as pnt

from matplotlib import pyplot as plt
# Out:
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDFLab_dev/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDFLab_dev/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDFLab_dev/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDFLab_dev/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
file_docking = pnt.utils.test_systems_path+'/Barnase-Barstar/dockings/docker_5_5.dpkl'
#file_docking = pnt.utils.test_systems_path+'/Barnase-Barstar/dockings/docker_8_4.dpkl'

# %%
docker = pnt.load(file_docking)

# %%
PE_net = docker.get_PotentialEnergyNetwork()

# %%
xx, pes = PE_net.get_potential_energy_1D_landscape()

# %%
plt.scatter(xx, pes._value, 0.1)
plt.ylim([4000,28000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (4000, 28000)

# %%
PE_net.make_potential_energy_basins()

# %%
docker.show_conformation(node_label=PE_net.cluster[0].label)

# %%
import nglview as nv
