# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import sys
sys.path.append('/home/diego/Projects/Pynterpred_devel/')
import pynterpred as pnt
import numpy as np
from matplotlib import pyplot as plt

# %%
Barnase     = '../testsystems/Barnase-Barstar/pdbs/Barnase.pdb'
Barstar     = '../testsystems/Barnase-Barstar/pdbs/Barstar.pdb'
force_field = 'amber14-all.xml'
pH          = 7.0

# %%
docking = pnt.pynterpred(Barnase, Barstar, force_field, pH, delta_x = 0.5, nside = 5)
xx1, pes1 = docking.get_potential_energy_1D_landscape()
del(docking)
# Out:
# 100%|██████████| 108/108 [00:53<00:00,  2.01it/s]

# %%
docking = pnt.pynterpred(Barnase, Barnase, force_field, pH, delta_x = 0.5, nside = 5)
xx2, pes2 = docking.get_potential_energy_1D_landscape()
del(docking)
# Out:
# 100%|██████████| 108/108 [01:28<00:00,  1.21it/s]

# %%
docking = pnt.pynterpred(Barstar, Barstar, force_field, pH, delta_x = 0.5, nside = 5)
xx3, pes3 = docking.get_potential_energy_1D_landscape()
del(docking)
# Out:
# 100%|██████████| 108/108 [00:43<00:00,  2.47it/s]

# %%
plt.scatter(xx1,pes1,0.1,label="Bb")
plt.scatter(xx2,pes2,0.1,label="BB")
plt.scatter(xx3,pes3,0.1,label="bb")
plt.legend()

plt.xlim([-10000,10000])
plt.ylim([-2000,4000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-2000, 4000)
