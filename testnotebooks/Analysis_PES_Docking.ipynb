# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import sys
sys.path.append('/home/diego/Projects/Pynterpred_devel/')
import time
import pynterpred as pnt
import numpy as np
from matplotlib import pyplot as plt
import dill as pickle

# %%
docker_loaded = pnt.load('../testsystems/Barnase-Barstar/dockings/docker_5_5.dpkl')

# %%
docker_loaded = pnt.load('../testsystems/E9034A_ETEC/dockings/docker_10_3.dpkl')

# %%
xx, pes = docker_loaded.get_potential_energy_1D_landscape()
pe_uncoupled = docker_loaded.potential_energy_uncoupled

# %%
plt.scatter(xx, (pes-pe_uncoupled)._value, 0.1)
plt.xlim([-4500,4500])
plt.ylim([-2500,20000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-2500, 20000)
